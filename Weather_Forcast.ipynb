# %%
import requests
import tkinter as tk
from tkinter import *
import matplotlib.pyplot as plt
def Gen_report():
    city_name = text_field.get("1.0",'end-1c')
    print(city_name)
    url = 'https://wttr.in/{}'.format("Nangal")
    data = requests.get(url)
    weather_report = data.text
    text_field.insert("1.0",weather_report)
    print(weather_report)
# Create the Tkinter window
window = tk.Tk()
window.title("Weather Forecaster")
# Create a label and entry for the city name input
label = tk.Label(window, text="Enter the name of the city:",
                 font=('Arial',20,'bold'),
                 highlightthickness=2, 
                 highlightcolor= "black")
label.pack()

entry = tk.Entry(window)
entry.pack()

# Create a button to generate the weather report
button = tk.Button(window, text="Get Weather Report", 
                   pady=2,
                   bg="white", 
                   fg="black",
                   command=Gen_report,
                   font=('Arial',8,'bold'))
button.pack()
# Create a text widget to display the weather report
text_field = tk.Text(window, 
                      bg="black", 
                      fg="yellow", 
                      height=500, 
                      width=500)
text_field.pack()

window.mainloop()
# Out:
# Weather report: Nangal
#
#    _`/"".-.     Patchy rain possible
#     ,\_(   ).   +31(36) °C
#      /(___(__)  ↗ 7 km/h
#        ‘ ‘ ‘ ‘  9 km
#       ‘ ‘ ‘ ‘   1.6 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 18 Jul ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy light r…│  _`/"".-.     Patchy rain po…│  _`/"".-.     Light rain sho…│  _`/"".-.     Patchy rain po…│
# │   ,\_(   ).   +29(33) °C     │   ,\_(   ).   +31(36) °C     │   ,\_(   ).   +28(32) °C     │   ,\_(   ).   +26(29) °C     │
# ...
